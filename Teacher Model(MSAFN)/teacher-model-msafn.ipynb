# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/vimeo2/vimeo90(15)/tri_trainlist.txt
# /kaggle/input/vimeo2/vimeo90(15)/tri_testlist.txt
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0745/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0745/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0745/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0111/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0111/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0111/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0362/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0362/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0362/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0105/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0105/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0105/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0217/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0217/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0217/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0947/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0947/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0947/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0795/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0795/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0795/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0785/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0785/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0785/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0264/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0264/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0264/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0035/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0035/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0035/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0327/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0327/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0327/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0639/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0639/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0639/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0109/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0109/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0109/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0095/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0095/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0095/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0818/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0818/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0818/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0987/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0987/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0987/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0549/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0549/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0549/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0534/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0534/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0534/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0866/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0866/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0866/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0570/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0570/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0570/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0872/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0872/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0872/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0225/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0225/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0225/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0886/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0886/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0886/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0451/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0451/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0451/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0477/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0477/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0477/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0981/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0981/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0981/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0618/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0618/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0618/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0696/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0696/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0696/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0953/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0953/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0953/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0020/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0020/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0020/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0050/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0050/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0050/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0386/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0386/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0386/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0184/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0184/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0184/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0588/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0588/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0588/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0311/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0311/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0311/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0334/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0334/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0334/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0501/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0501/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0501/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0347/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0347/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0347/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0372/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0372/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0372/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0754/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0754/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0754/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0949/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0949/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0949/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0659/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0659/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0659/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0699/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0699/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0699/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0812/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0812/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0812/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0734/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0734/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0734/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0732/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0732/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0732/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0516/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0516/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0516/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0865/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0865/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0865/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0851/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0851/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0851/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0086/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0086/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0086/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0048/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0048/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0048/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0202/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0202/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0202/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0997/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0997/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0997/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0496/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0496/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0496/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0429/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0429/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0429/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0125/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0125/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0125/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0342/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0342/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0342/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0778/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0778/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0778/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0555/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0555/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0555/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0902/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0902/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0902/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0951/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0951/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0951/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0230/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0230/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0230/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0254/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0254/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0254/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0343/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0343/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0343/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0317/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0317/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0317/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0589/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0589/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0589/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0923/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0923/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0923/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0041/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0041/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0041/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0071/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0071/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0071/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0204/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0204/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0204/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0801/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0801/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0801/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0439/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0439/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0439/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0749/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0749/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0749/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0258/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0258/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0258/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0521/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0521/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0521/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0533/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0533/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0533/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0751/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0751/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0751/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0397/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0397/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0397/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0298/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0298/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0298/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0982/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0982/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0982/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0360/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0360/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0360/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0195/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0195/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0195/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0726/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0726/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0726/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0183/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0183/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0183/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0599/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0599/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0599/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0390/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0390/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0390/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0972/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0972/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0972/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0500/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0500/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0500/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0136/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0136/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0136/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0954/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0954/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0954/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0642/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0642/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0642/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0805/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0805/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0805/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0740/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0740/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0740/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0994/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0994/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0994/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0693/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0693/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0693/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0110/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0110/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0110/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0024/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0024/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0024/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0636/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0636/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0636/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0774/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0774/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0774/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0265/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0265/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0265/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0602/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0602/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0602/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0921/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0921/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0921/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0605/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0605/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0605/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0960/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0960/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0960/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0737/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0737/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0737/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0671/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0671/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0671/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0250/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0250/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0250/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0807/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0807/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0807/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0007/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0007/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0007/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0968/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0968/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0968/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0352/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0352/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0352/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0969/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0969/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0969/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0308/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0308/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0308/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0538/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0538/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0538/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0531/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0531/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0531/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0546/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0546/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0546/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0070/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0070/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0070/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0432/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0432/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0432/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0455/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0455/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0455/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0275/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0275/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0275/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0656/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0656/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0656/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0282/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0282/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0282/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0484/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0484/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0484/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0843/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0843/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0843/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0402/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0402/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0402/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0840/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0840/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0840/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0687/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0687/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0687/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0694/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0694/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0694/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0897/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0897/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0897/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0159/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0159/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0159/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0814/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0814/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0814/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0813/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0813/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0813/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0709/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0709/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0709/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0622/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0622/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0622/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0601/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0601/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0601/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0575/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0575/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0575/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0995/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0995/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0995/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0210/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0210/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0210/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0544/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0544/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0544/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0316/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0316/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0316/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0220/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0220/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0220/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0577/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0577/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0577/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0513/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0513/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0513/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0153/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0153/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0153/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0884/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0884/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0884/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0351/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0351/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0351/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0211/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0211/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0211/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0419/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0419/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0419/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0985/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0985/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0985/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0581/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0581/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0581/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0780/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0780/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0780/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0804/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0804/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0804/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0356/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0356/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0356/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0719/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0719/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0719/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0922/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0922/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0922/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0104/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0104/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0104/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0817/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0817/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0817/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0323/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0323/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0323/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0837/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0837/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0837/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0944/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0944/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0944/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0963/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0963/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0963/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0481/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0481/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0481/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0933/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0933/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0933/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0939/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0939/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0939/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0607/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0607/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0607/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0627/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0627/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0627/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0470/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0470/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0470/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0076/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0076/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0076/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0561/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0561/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0561/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0986/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0986/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0986/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0505/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0505/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0505/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0196/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0196/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0196/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0835/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0835/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0835/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0493/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0493/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0493/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0030/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0030/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0030/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0269/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0269/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0269/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0200/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0200/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0200/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0068/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0068/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0068/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0399/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0399/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0399/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0209/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0209/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0209/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0328/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0328/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0328/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0825/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0825/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0825/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0796/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0796/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0796/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0428/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0428/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0428/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0873/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0873/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0873/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0733/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0733/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0733/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0824/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0824/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0824/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0292/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0292/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0292/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0889/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0889/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0889/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0707/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0707/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0707/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0289/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0289/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0289/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0172/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0172/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0172/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0683/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0683/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0683/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0457/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0457/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0457/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0163/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0163/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0163/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0878/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0878/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0878/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0259/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0259/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0259/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0706/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0706/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0706/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0965/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0965/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0965/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0674/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0674/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0674/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0833/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0833/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0833/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0937/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0937/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0937/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0234/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0234/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0234/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0192/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0192/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0192/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0914/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0914/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0914/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0313/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0313/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0313/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0499/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0499/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0499/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0920/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0920/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0920/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0714/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0714/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0714/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0991/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0991/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0991/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0769/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0769/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0769/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0644/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0644/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0644/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0783/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0783/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0783/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0856/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0856/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0856/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0522/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0522/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0522/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0037/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0037/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0037/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0984/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0984/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0984/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0039/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0039/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0039/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0956/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0956/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0956/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0468/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0468/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0468/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0337/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0337/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0337/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0440/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0440/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0440/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0077/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0077/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0077/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0445/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0445/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0445/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0901/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0901/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0901/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0448/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0448/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0448/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0519/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0519/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0519/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0193/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0193/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0193/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0862/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0862/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0862/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0294/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0294/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0294/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0611/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0611/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0611/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0512/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0512/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0512/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0548/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0548/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0548/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0803/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0803/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0803/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0861/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0861/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0861/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0325/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0325/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0325/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0898/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0898/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0898/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0582/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0582/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0582/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0838/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0838/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0838/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0881/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0881/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0881/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0087/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0087/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0087/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0080/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0080/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0080/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0236/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0236/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0236/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0261/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0261/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0261/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0379/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0379/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0379/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0682/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0682/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0682/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0391/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0391/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0391/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0333/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0333/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0333/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0971/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0971/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0971/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0630/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0630/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0630/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0031/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0031/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0031/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0102/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0102/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0102/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0799/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0799/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0799/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0320/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0320/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0320/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0280/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0280/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0280/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0435/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0435/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0435/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0542/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0542/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0542/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00013/0044/im3.png
# ...
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0703/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0703/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0703/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0181/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0181/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0181/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0186/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0186/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0186/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0748/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0748/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0748/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0620/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0620/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0620/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0157/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0157/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0157/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0127/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0127/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0127/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0591/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0591/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0591/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0494/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0494/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0494/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0420/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0420/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0420/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0792/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0792/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0792/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0526/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0526/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0526/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0339/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0339/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0339/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0330/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0330/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0330/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0911/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0911/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0911/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0626/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0626/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0626/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0417/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0417/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0417/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0466/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0466/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0466/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0736/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0736/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0736/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0905/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0905/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0905/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0492/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0492/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0492/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0486/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0486/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0486/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0647/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0647/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0647/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0304/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0304/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0304/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0433/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0433/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0433/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0060/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0060/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0060/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0871/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0871/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0871/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0165/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0165/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0165/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0430/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0430/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0430/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0268/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0268/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0268/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0761/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0761/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0761/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0926/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0926/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0926/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0145/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0145/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0145/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0753/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0753/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0753/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0823/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0823/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0823/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0839/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0839/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0839/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0941/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0941/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0941/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0967/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0967/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0967/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0768/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0768/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0768/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0248/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0248/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0248/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0705/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0705/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0705/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0069/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0069/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0069/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0421/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0421/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0421/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0518/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0518/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0518/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0520/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0520/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0520/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0358/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0358/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0358/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0942/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0942/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0942/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0558/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0558/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0558/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0996/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0996/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0996/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0836/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0836/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0836/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0188/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0188/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0188/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0684/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0684/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0684/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0189/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0189/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0189/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0046/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0046/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0046/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0231/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0231/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0231/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0553/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0553/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0553/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0503/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0503/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0503/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0122/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0122/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0122/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0811/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0811/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0811/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0931/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0931/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0931/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0363/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0363/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0363/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0758/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0758/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0758/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0658/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0658/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0658/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0530/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0530/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0530/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0689/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0689/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0689/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0868/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0868/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0868/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0832/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0832/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0832/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0120/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0120/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0120/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0164/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0164/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0164/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0341/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0341/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0341/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0672/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0672/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0672/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0894/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0894/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0894/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0735/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0735/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0735/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0412/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0412/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0412/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0056/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0056/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0056/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0283/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0283/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0283/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0731/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0731/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0731/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0821/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0821/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0821/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0131/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0131/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0131/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0324/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0324/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0324/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0890/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0890/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0890/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0826/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0826/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0826/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0027/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0027/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0027/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0299/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0299/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0299/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0357/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0357/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0357/im2.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0651/im3.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0651/im1.png
# /kaggle/input/vimeo2/vimeo90(15)/sequences/00005/0651/im2.png

# %% [markdown]
# # ***Teacher Model Script***

# %%
# %%writefile teacher_training.py
# -*- coding: utf-8 -*-
"""Enhanced Advanced Image Sharpening Teacher Model with NaN Fixes"""
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import OneCycleLR
from torch.cuda.amp import autocast, GradScaler
from tqdm import tqdm
import numpy as np
from PIL import Image
import glob
import random
import warnings

# Suppress warnings
warnings.filterwarnings('ignore')

# Initialize console logging
print = lambda *args, **kwargs: __builtins__.print(*args, **kwargs, flush=True)

# =================================
# 1. Advanced Model Architecture (Unchanged)
# =================================
class MultiScaleGate(nn.Module):
    """Multi-scale channel attention gate"""
    def __init__(self, channels, reduction=16):
        super().__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(channels, channels//reduction),
            nn.ReLU(inplace=True),
            nn.Linear(channels//reduction, channels),
            nn.Sigmoid()
        )
    
    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1, 1)
        return x * y

class ResidualDenseBlock(nn.Module):
    """Stochastic depth residual dense block"""
    def __init__(self, channels, drop_prob=0.2):
        super().__init__()
        self.drop_prob = drop_prob
        
        self.conv1 = nn.Conv2d(channels, channels, 3, padding=1)
        self.conv2 = nn.Conv2d(channels*2, channels, 3, padding=1)
        self.conv3 = nn.Conv2d(channels*3, channels, 3, padding=1)
        self.gate = MultiScaleGate(channels)
        self.lrelu = nn.LeakyReLU(0.2)
        
    def forward(self, x):
        if self.training and random.random() < self.drop_prob:
            return x
            
        x1 = self.lrelu(self.conv1(x))
        x2 = self.lrelu(self.conv2(torch.cat([x, x1], 1)))
        x3 = self.lrelu(self.conv3(torch.cat([x, x1, x2], 1)))
        return x + self.gate(x3)

class RecurrentRefinement(nn.Module):
    """GRU-based refinement module"""
    def __init__(self, channels):
        super().__init__()
        self.conv_z = nn.Conv2d(channels*2, channels, 3, padding=1)
        self.conv_r = nn.Conv2d(channels*2, channels, 3, padding=1)
        self.conv_h = nn.Conv2d(channels*2, channels, 3, padding=1)
        
    def forward(self, x, h):
        if h is None:
            h = torch.zeros_like(x)
            
        xh = torch.cat([x, h], 1)
        z = torch.sigmoid(self.conv_z(xh))
        r = torch.sigmoid(self.conv_r(xh))
        h_hat = torch.tanh(self.conv_h(torch.cat([x, r*h], 1)))
        return (1 - z) * h + z * h_hat

class MSAFN(nn.Module):
    """Multi-Scale Attention Fusion Network"""
    def __init__(self):
        super().__init__()
        # Initial feature extraction
        self.conv_init = nn.Conv2d(3, 64, 3, padding=1)
        
        # Multi-scale processing paths
        self.scale1 = nn.Sequential(
            ResidualDenseBlock(64),
            MultiScaleGate(64)
        )
        self.scale2 = nn.Sequential(
            nn.AvgPool2d(2),
            ResidualDenseBlock(64),
            MultiScaleGate(64)
        )
        self.scale3 = nn.Sequential(
            nn.AvgPool2d(4),
            ResidualDenseBlock(64),
            MultiScaleGate(64)
        )
        
        # Feature fusion
        self.fusion = nn.Sequential(
            nn.Conv2d(192, 128, 1),
            nn.LeakyReLU(0.2)
        )
        
        # Residual dense blocks
        self.res_blocks = nn.Sequential(
            *[ResidualDenseBlock(128) for _ in range(8)]
        )
        
        # Recurrent refinement
        self.refinement = RecurrentRefinement(128)
        
        # Reconstruction
        self.recon = nn.Sequential(
            nn.Conv2d(128, 64, 3, padding=1),
            nn.LeakyReLU(0.2),
            nn.Conv2d(64, 3, 3, padding=1)
        )
    
    def forward(self, x):
        # Initial features
        x0 = self.conv_init(x)
        
        # Multi-scale processing
        s1 = self.scale1(x0)
        s2 = self.scale2(x0)
        s3 = self.scale3(x0)
        
        # Upsample and align scales
        s2 = F.interpolate(s2, size=s1.shape[2:], mode='bilinear', align_corners=False)
        s3 = F.interpolate(s3, size=s1.shape[2:], mode='bilinear', align_corners=False)
        
        # Feature fusion
        features = self.fusion(torch.cat([s1, s2, s3], dim=1))
        
        # Residual processing
        features = self.res_blocks(features)
        
        # Recurrent refinement (3 steps)
        h = None
        for _ in range(3):
            h = self.refinement(features, h)
        features = h
        
        # Reconstruction
        return self.recon(features)

# =================================
# 2. Dataset with Enhanced Augmentation Safety
# =================================
class Vimeo90KDataset(Dataset):
    def __init__(self, data_path, patch_size=48, aug_intensity=1.0):
        self.data_path = data_path
        self.patch_size = patch_size
        self.aug_intensity = aug_intensity
        self.image_paths = self._load_image_paths()
        print(f"Loaded {len(self.image_paths)} images")
        
    def _load_image_paths(self):
        """Load image paths from the specified dataset path"""
        image_paths = []
        
        # Find all PNG images in the dataset
        search_path = os.path.join(self.data_path, "**", "*.png")
        image_paths = glob.glob(search_path, recursive=True)
        
        # If no images found, try alternative patterns
        if len(image_paths) == 0:
            print("No images found with recursive PNG search. Trying alternative patterns...")
            # Try looking in subdirectories
            for root, dirs, files in os.walk(self.data_path):
                for file in files:
                    if file.lower().endswith('.png'):
                        image_paths.append(os.path.join(root, file))
        
        print(f"Found {len(image_paths)} images in dataset")
        return image_paths
    
    def _augment(self, img):
        """Dynamic intensity augmentation with NaN protection"""
        img = np.array(img).astype(np.float32) / 255.0
        
        # Random flips
        if random.random() < 0.5*self.aug_intensity:
            img = np.flip(img, axis=1).copy()
        if random.random() < 0.5*self.aug_intensity:
            img = np.flip(img, axis=0).copy()
            
        # Random rotation
        if random.random() < 0.3*self.aug_intensity:
            angle = random.choice([90, 180, 270])
            img = np.rot90(img, k=angle//90).copy()
            
        # Color jitter with clamping
        if random.random() < 0.5*self.aug_intensity:
            brightness = 0.8 + 0.4*random.random()
            img = img * brightness
            img = np.clip(img, 0, 1)
            
        # Add noise with clamping
        if random.random() < 0.3*self.aug_intensity:
            noise = np.random.normal(0, 0.02*self.aug_intensity, img.shape)
            img = np.clip(img + noise, 0, 1)
            
        # Ensure no NaN/Inf values
        if np.isnan(img).any() or np.isinf(img).any():
            print("Warning: NaN/Inf detected after augmentation! Replacing with zeros.")
            img = np.zeros_like(img)
            
        return img
    
    def increase_augmentation(self):
        """Dynamically increase augmentation intensity with safety cap"""
        self.aug_intensity = min(1.5, self.aug_intensity + 0.1)
        print(f"Augmentation intensity increased to: {self.aug_intensity:.1f}")
    
    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, idx):
        try:
            hr_img = Image.open(self.image_paths[idx]).convert('RGB')
            hr_img = self._augment(hr_img)
            
            # Degradation simulation
            H, W, _ = hr_img.shape
            hr_pil = Image.fromarray((hr_img*255).astype(np.uint8))
            lr_pil = hr_pil.resize((max(1, W//4), max(1, H//4)), Image.BICUBIC)
            lr_pil = lr_pil.resize((W, H), Image.BICUBIC)
            lr_img = np.array(lr_pil) / 255.0
            
            # Extract patch
            x = random.randint(0, max(0, H - self.patch_size))
            y = random.randint(0, max(0, W - self.patch_size))
            hr_patch = hr_img[x:x+self.patch_size, y:y+self.patch_size]
            lr_patch = lr_img[x:x+self.patch_size, y:y+self.patch_size]
            
            # Final NaN check
            if np.isnan(hr_patch).any() or np.isnan(lr_patch).any():
                print(f"NaN detected in image {self.image_paths[idx]}! Using fallback.")
                hr_patch = np.zeros((self.patch_size, self.patch_size, 3), dtype=np.float32)
                lr_patch = np.zeros((self.patch_size, self.patch_size, 3), dtype=np.float32)
            
            return (
                torch.tensor(lr_patch).permute(2, 0, 1).float(),
                torch.tensor(hr_patch).permute(2, 0, 1).float()
            )
        except Exception as e:
            print(f"Error loading image {self.image_paths[idx]}: {e}")
            # Return a random dummy image
            dummy = np.zeros((self.patch_size, self.patch_size, 3), dtype=np.float32)
            return (
                torch.tensor(dummy).permute(2, 0, 1).float(),
                torch.tensor(dummy).permute(2, 0, 1).float()
            )

# =================================
# 3. Enhanced Training Utilities
# =================================
class HybridLoss(nn.Module):
    def __init__(self, device):
        super().__init__()
        self.l1 = nn.L1Loss()
        self.device = device
        
    def forward(self, pred, target):
        # Check for NaN inputs
        if torch.isnan(pred).any() or torch.isnan(target).any():
            print("Warning: NaN detected in loss calculation inputs!")
            return torch.tensor(0.1, device=self.device, requires_grad=True)
        
        # Pixel loss
        l1 = self.l1(pred, target)
        
        # Structural similarity with stabilization
        C1 = (0.01 * 1) ** 2
        C2 = (0.03 * 1) ** 2
        EPSILON = 1e-8  # Stabilization term
        
        mu_x = pred.mean(dim=[1, 2, 3], keepdim=True)
        mu_y = target.mean(dim=[1, 2, 3], keepdim=True)
        
        sigma_x = pred.var(dim=[1, 2, 3], keepdim=True, unbiased=False) + EPSILON
        sigma_y = target.var(dim=[1, 2, 3], keepdim=True, unbiased=False) + EPSILON
        sigma_xy = ((pred - mu_x) * (target - mu_y)).mean(dim=[1, 2, 3], keepdim=True)
        
        numerator = (2 * mu_x * mu_y + C1) * (2 * sigma_xy + C2)
        denominator = (mu_x**2 + mu_y**2 + C1) * (sigma_x + sigma_y + C2) + EPSILON
        
        ssim_map = numerator / denominator
        ssim_loss = 1 - ssim_map.mean()
        
        return 0.7 * l1 + 0.3 * ssim_loss

def centralize_gradients(model):
    """Gradient Centralization (GC)"""
    for param in model.parameters():
        if param.grad is not None:
            grad = param.grad.data
            if grad.dim() > 1:
                mean = torch.mean(grad, dim=tuple(range(1, grad.dim())), keepdim=True)
                param.grad.data = grad - mean

# =================================
# 4. Enhanced Plateau Detection & Handling
# =================================
class PlateauBreaker:
    def __init__(self, model, optimizer, dataloader):
        self.model = model
        self.optimizer = optimizer
        self.dataloader = dataloader
        self.best_ssim = 0
        self.plateau_count = 0
        self.max_lr = 3e-4  # Absolute maximum LR
        
    def __call__(self, current_ssim, epoch):
        if current_ssim > self.best_ssim + 0.001:
            self.best_ssim = current_ssim
            self.plateau_count = 0
            return False
            
        self.plateau_count += 1
        if self.plateau_count < 2:  # Allow 2 epochs plateau
            return False
            
        print(f"Plateau detected at epoch {epoch}! Applying countermeasures...")
        self.plateau_count = 0
        
        # 1. Conservative LR boost (capped)
        for g in self.optimizer.param_groups:
            new_lr = min(g['lr'] * 1.2, self.max_lr)  # 20% increase max
            g['lr'] = new_lr
        print(f"LR increased to {self.optimizer.param_groups[0]['lr']:.2e}")
        
        # 2. Increase augmentation
        self.dataloader.dataset.increase_augmentation()
        
        return True

# =================================
# 5. Training Loop with TQDM Bars
# =================================
def print_metrics(epoch, loss, val_ssim, lr, time_elapsed, gpu_mem, iterations):
    print(f"\n{'='*50}")
    print(f"Epoch {epoch} | Time: {time_elapsed:.1f}s")
    print(f"Loss: {loss:.4f} | SSIM: {val_ssim:.4f} | LR: {lr:.1e}")
    print(f"GPU Memory: {gpu_mem} | Iterations: {iterations}")
    print(f"{'='*50}\n")

# =================================
# 6. Enhanced Main Training Function
# =================================
def main():
    # Configuration
    DATA_PATH = "/kaggle/input/vimeo2/vimeo90(15)/sequences"
    TOTAL_EPOCHS = 42
    BATCH_SIZE = 64
    NUM_WORKERS = 4
    DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
    
    print(f"Starting training on {DEVICE}...")
    print(f"Dataset path: {DATA_PATH}")
    
    # Initialize model
    model = MSAFN().to(DEVICE)
    num_gpus = torch.cuda.device_count()
    if num_gpus > 1:
        model = nn.DataParallel(model)
        print(f"Using {num_gpus} GPUs!")
    
    # Print model summary
    total_params = sum(p.numel() for p in model.parameters())
    print(f"Model parameters: {total_params/1e6:.2f}M")
    
    # Loss and optimizer
    criterion = HybridLoss(DEVICE)
    optimizer = optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-4)
    
    # Create dataset and loader
    try:
        full_dataset = Vimeo90KDataset(DATA_PATH, 48)
        full_loader = DataLoader(
            full_dataset, batch_size=BATCH_SIZE, 
            shuffle=True, num_workers=NUM_WORKERS, pin_memory=True
        )
        print(f"Loaded {len(full_dataset)} images | Batches: {len(full_loader)}")
        
        # Check if dataset is empty
        if len(full_dataset) == 0:
            print("Error: No images found in dataset!")
            return
    except Exception as e:
        print(f"Error loading dataset: {e}")
        return

    # Scheduler
    total_steps = len(full_loader) * TOTAL_EPOCHS
    scheduler = OneCycleLR(
        optimizer, 
        max_lr=3e-4,
        total_steps=total_steps,
        pct_start=0.2,
        anneal_strategy='cos'
    )
    
    # Training state
    scaler = GradScaler()
    plateau_breaker = PlateauBreaker(model, optimizer, full_loader)
    best_ssim = 0
    iteration_counter = 0
    
    # GPU memory tracking
    def get_gpu_memory():
        if not torch.cuda.is_available():
            return "N/A"
        return f"{torch.cuda.memory_allocated()//1024**2}/{torch.cuda.max_memory_allocated()//1024**2} MB"
    
    # Start training
    for epoch in range(1, TOTAL_EPOCHS+1):
        epoch_start = time.time()
        model.train()
        total_loss = 0
        skipped_batches = 0
        
        # Create progress bar for batches
        batch_bar = tqdm(
            total=len(full_loader), 
            desc=f"Epoch {epoch}/{TOTAL_EPOCHS}", 
            unit="batch",
            bar_format="{l_bar}{bar:30}{r_bar}",
            position=0
        )
        
        # Batch processing
        for batch_idx, (lr, hr) in enumerate(full_loader):
            iteration_counter += 1
            
            lr, hr = lr.to(DEVICE), hr.to(DEVICE)
            optimizer.zero_grad()
            
            # Skip batch if inputs contain NaN
            if torch.isnan(lr).any() or torch.isnan(hr).any():
                skipped_batches += 1
                batch_bar.set_postfix_str("Skipped NaN batch")
                batch_bar.update(1)
                continue
            
            with autocast():
                sr = model(lr)
                
                # Skip batch if output contains NaN
                if torch.isnan(sr).any():
                    skipped_batches += 1
                    batch_bar.set_postfix_str("Skipped NaN output")
                    batch_bar.update(1)
                    continue
                
                loss = criterion(sr, hr)
            
            # Skip batch if loss is NaN
            if torch.isnan(loss).any():
                skipped_batches += 1
                optimizer.zero_grad()
                batch_bar.set_postfix_str("Skipped NaN loss")
                batch_bar.update(1)
                continue
            
            scaler.scale(loss).backward()
            centralize_gradients(model)
            
            # Gradient clipping to prevent explosions
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            
            scaler.step(optimizer)
            scaler.update()
            scheduler.step()
            
            total_loss += loss.item()
            
            # Update progress bar
            batch_bar.set_postfix(
                loss=f"{loss.item():.4f}", 
                lr=f"{optimizer.param_groups[0]['lr']:.1e}",
                gpu=get_gpu_memory(),
                skipped=skipped_batches
            )
            batch_bar.update(1)
        
        # Close batch bar
        batch_bar.close()
        
        # Validation
        model.eval()
        val_ssim = 0
        val_batches = min(20, len(full_loader))
        valid_val_batches = 0
        
        if val_batches == 0:
            print("No batches available for validation!")
            avg_val_ssim = 0
        else:
            # Create validation progress bar
            val_bar = tqdm(
                total=val_batches,
                desc="Validation",
                unit="batch",
                bar_format="{l_bar}{bar:30}{r_bar}",
                position=0,
                leave=True
            )
            
            with torch.no_grad():
                for i, (lr, hr) in enumerate(full_loader):
                    if i >= val_batches:
                        break
                        
                    lr, hr = lr.to(DEVICE), hr.to(DEVICE)
                    
                    # Skip validation batch with NaN
                    if torch.isnan(lr).any() or torch.isnan(hr).any():
                        val_bar.update(1)
                        continue
                        
                    sr = model(lr)
                    
                    # Skip validation batch with NaN output
                    if torch.isnan(sr).any():
                        val_bar.update(1)
                        continue
                    
                    # Manual SSIM calculation with stabilization
                    C1 = (0.01 * 1) ** 2
                    C2 = (0.03 * 1) ** 2
                    EPSILON = 1e-8
                    
                    mu_x = sr.mean(dim=[1, 2, 3], keepdim=True)
                    mu_y = hr.mean(dim=[1, 2, 3], keepdim=True)
                    
                    sigma_x = sr.var(dim=[1, 2, 3], keepdim=True, unbiased=False) + EPSILON
                    sigma_y = hr.var(dim=[1, 2, 3], keepdim=True, unbiased=False) + EPSILON
                    sigma_xy = ((sr - mu_x) * (hr - mu_y)).mean(dim=[1, 2, 3], keepdim=True)
                    
                    numerator = (2 * mu_x * mu_y + C1) * (2 * sigma_xy + C2)
                    denominator = (mu_x**2 + mu_y**2 + C1) * (sigma_x + sigma_y + C2) + EPSILON
                    
                    ssim_map = numerator / denominator
                    val_ssim += ssim_map.mean().item()
                    valid_val_batches += 1
                    
                    # Update validation bar
                    val_bar.update(1)
            
            # Close validation bar
            val_bar.close()
            
            # Calculate metrics
            avg_val_ssim = val_ssim / valid_val_batches if valid_val_batches > 0 else 0
        
        # Calculate metrics
        actual_batches = len(full_loader) - skipped_batches
        avg_loss = total_loss / actual_batches if actual_batches > 0 else 0
        elapsed = time.time() - epoch_start
        lr = optimizer.param_groups[0]['lr']
        gpu_mem = get_gpu_memory()
        
        # Print epoch summary
        print_metrics(epoch, avg_loss, avg_val_ssim, lr, elapsed, gpu_mem, iteration_counter)
        if skipped_batches > 0:
            print(f"Warning: Skipped {skipped_batches}/{len(full_loader)} batches due to NaN")
        
        # Plateau detection
        if plateau_breaker(avg_val_ssim, epoch):
            # Reset plateau counter after action
            pass
        
        # Save best model
        if avg_val_ssim > best_ssim:
            best_ssim = avg_val_ssim
            save_path = "/kaggle/working/best_model.pth"
            if num_gpus > 1:
                torch.save(model.module.state_dict(), save_path)
            else:
                torch.save(model.state_dict(), save_path)
            print(f"Saved best model with SSIM: {best_ssim:.4f}")
    
    # Final save
    save_path = "/kaggle/working/final_model.pth"
    if num_gpus > 1:
        torch.save(model.module.state_dict(), save_path)
    else:
        torch.save(model.state_dict(), save_path)
    
    print(f"Training complete! Best SSIM: {best_ssim:.4f}")
    
    # Create download link
    try:
        from IPython.display import FileLink
        print("\nDownload Model:", FileLink(save_path))
    except:
        print(f"Model saved at {save_path}")

if __name__ == "__main__":
    main()
# Out:
# Overwriting teacher_training.py

# %%
# !python3 teacher_training.py
# Out:
# Starting training on cuda...
# Dataset path: /kaggle/input/vimeo2/vimeo90(15)/sequences
# Using 2 GPUs!
# Model parameters: 8.75M
# Found 44598 images in dataset
# Loaded 44598 images
# Loaded 44598 images | Batches: 697
# Epoch 1/42: 100%|██████████████████████████████| 697/697 [07:07<00:00,  1.63batc
# Validation: 100%|██████████████████████████████| 20/20 [00:15<00:00,  1.31batch/
#
# ==================================================
# Epoch 1 | Time: 442.9s
# Loss: 0.1589 | SSIM: 0.8810 | LR: 2.2e-05
# GPU Memory: 187/2346 MB | Iterations: 697
# ==================================================
#
# Saved best model with SSIM: 0.8810
# Epoch 2/42: 100%|██████████████████████████████| 697/697 [07:17<00:00,  1.59batc
# Validation: 100%|██████████████████████████████| 20/20 [00:16<00:00,  1.22batch/
#
# ==================================================
# Epoch 2 | Time: 454.1s
# Loss: 0.0569 | SSIM: 0.9125 | LR: 5.0e-05
# GPU Memory: 187/2346 MB | Iterations: 1394
# ==================================================
#
# Saved best model with SSIM: 0.9125
# Epoch 3/42: 100%|██████████████████████████████| 697/697 [07:15<00:00,  1.60batc
# Validation: 100%|██████████████████████████████| 20/20 [00:15<00:00,  1.28batch/
#
# ==================================================
# Epoch 3 | Time: 451.6s
# Loss: 0.0496 | SSIM: 0.9299 | LR: 9.4e-05
# GPU Memory: 187/2346 MB | Iterations: 2091
# ==================================================
#
# Saved best model with SSIM: 0.9299
# Epoch 4/42: 100%|██████████████████████████████| 697/697 [07:10<00:00,  1.62batc
# Validation: 100%|██████████████████████████████| 20/20 [00:15<00:00,  1.26batch/
#
# ==================================================
# Epoch 4 | Time: 446.3s
# Loss: 0.0455 | SSIM: 0.9318 | LR: 1.5e-04
# GPU Memory: 187/2346 MB | Iterations: 2788
# ==================================================
#
# Saved best model with SSIM: 0.9318
# Epoch 5/42: 100%|██████████████████████████████| 697/697 [07:08<00:00,  1.63batc
# Validation: 100%|██████████████████████████████| 20/20 [00:14<00:00,  1.36batch/
#
# ==================================================
# Epoch 5 | Time: 443.0s
# Loss: 0.0424 | SSIM: 0.9351 | LR: 2.0e-04
# GPU Memory: 187/2346 MB | Iterations: 3485
# ==================================================
#
# Saved best model with SSIM: 0.9351
# Epoch 6/42: 100%|██████████████████████████████| 697/697 [07:05<00:00,  1.64batc
# Validation: 100%|██████████████████████████████| 20/20 [00:14<00:00,  1.35batch/
#
# ==================================================
# Epoch 6 | Time: 440.6s
# Loss: 0.0407 | SSIM: 0.9388 | LR: 2.5e-04
# GPU Memory: 186/2346 MB | Iterations: 4182
# ==================================================
#
# Saved best model with SSIM: 0.9388
# Epoch 7/42: 100%|██████████████████████████████| 697/697 [07:06<00:00,  1.63batc
# Validation: 100%|██████████████████████████████| 20/20 [00:14<00:00,  1.40batch/
#
# ==================================================
# Epoch 7 | Time: 440.8s
# Loss: 0.0401 | SSIM: 0.9356 | LR: 2.8e-04
# GPU Memory: 187/2346 MB | Iterations: 4879
# ==================================================
#
# Epoch 8/42: 100%|██████████████████████████████| 697/697 [07:13<00:00,  1.61batc
# Validation: 100%|██████████████████████████████| 20/20 [00:14<00:00,  1.35batch/
#
# ==================================================
# Epoch 8 | Time: 448.4s
# Loss: 0.0390 | SSIM: 0.9423 | LR: 3.0e-04
# GPU Memory: 187/2346 MB | Iterations: 5576
# ==================================================
#
# Saved best model with SSIM: 0.9423
# Epoch 9/42: 100%|██████████████████████████████| 697/697 [07:16<00:00,  1.60batc
# Validation: 100%|██████████████████████████████| 20/20 [00:15<00:00,  1.29batch/
#
# ==================================================
# Epoch 9 | Time: 452.2s
# Loss: 0.0383 | SSIM: 0.9316 | LR: 3.0e-04
# GPU Memory: 187/2346 MB | Iterations: 6273
# ==================================================
#
# Epoch 10/42: 100%|██████████████████████████████| 697/697 [07:17<00:00,  1.59bat
# Validation: 100%|██████████████████████████████| 20/20 [00:16<00:00,  1.22batch/
#
# ==================================================
# Epoch 10 | Time: 454.4s
# Loss: 0.0374 | SSIM: 0.9415 | LR: 3.0e-04
# GPU Memory: 187/2346 MB | Iterations: 6970
# ==================================================
#
# Plateau detected at epoch 10! Applying countermeasures...
# LR increased to 3.00e-04
# Augmentation intensity increased to: 1.1
# Epoch 11/42: 100%|██████████████████████████████| 697/697 [07:23<00:00,  1.57bat
# Validation: 100%|██████████████████████████████| 20/20 [00:16<00:00,  1.24batch/
#
# ==================================================
# Epoch 11 | Time: 459.8s
# Loss: 0.0376 | SSIM: 0.9422 | LR: 3.0e-04
# GPU Memory: 187/2346 MB | Iterations: 7667
# ==================================================
#
# Epoch 12/42: 100%|██████████████████████████████| 697/697 [07:27<00:00,  1.56bat
# Validation: 100%|██████████████████████████████| 20/20 [00:16<00:00,  1.24batch/
#
# ==================================================
# Epoch 12 | Time: 463.9s
# Loss: 0.0374 | SSIM: 0.9375 | LR: 2.9e-04
# GPU Memory: 187/2346 MB | Iterations: 8364
# ==================================================
#
# Plateau detected at epoch 12! Applying countermeasures...
# LR increased to 3.00e-04
# Augmentation intensity increased to: 1.2
# Epoch 13/42: 100%|██████████████████████████████| 697/697 [07:33<00:00,  1.54bat
# Validation: 100%|██████████████████████████████| 20/20 [00:15<00:00,  1.26batch/
#
# ==================================================
# Epoch 13 | Time: 469.7s
# Loss: 0.0380 | SSIM: 0.9403 | LR: 2.9e-04
# GPU Memory: 186/2347 MB | Iterations: 9061
# ==================================================
#
# Epoch 14/42: 100%|██████████████████████████████| 697/697 [07:31<00:00,  1.55bat
# Validation: 100%|██████████████████████████████| 20/20 [00:16<00:00,  1.21batch/
#
# ==================================================
# Epoch 14 | Time: 467.6s
# Loss: 0.0376 | SSIM: 0.9388 | LR: 2.8e-04
# GPU Memory: 186/2347 MB | Iterations: 9758
# ==================================================
#
# Plateau detected at epoch 14! Applying countermeasures...
# LR increased to 3.00e-04
# Augmentation intensity increased to: 1.3
# Epoch 15/42: 100%|██████████████████████████████| 697/697 [07:30<00:00,  1.55bat
# Validation: 100%|██████████████████████████████| 20/20 [00:16<00:00,  1.19batch/
#
# ==================================================
# Epoch 15 | Time: 467.4s
# Loss: 0.0385 | SSIM: 0.9379 | LR: 2.7e-04
# GPU Memory: 188/2347 MB | Iterations: 10455
# ==================================================
#
# Epoch 16/42: 100%|██████████████████████████████| 697/697 [07:50<00:00,  1.48bat
# Validation: 100%|██████████████████████████████| 20/20 [00:15<00:00,  1.28batch/
#
# ==================================================
# Epoch 16 | Time: 485.9s
# Loss: 0.0383 | SSIM: 0.9391 | LR: 2.6e-04
# GPU Memory: 188/2347 MB | Iterations: 11152
# ==================================================
#
# Plateau detected at epoch 16! Applying countermeasures...
# LR increased to 3.00e-04
# Augmentation intensity increased to: 1.4
# Epoch 17/42: 100%|██████████████████████████████| 697/697 [07:49<00:00,  1.49bat
# Validation: 100%|██████████████████████████████| 20/20 [00:16<00:00,  1.22batch/
#
# ==================================================
# Epoch 17 | Time: 485.7s
# Loss: 0.0396 | SSIM: 0.9367 | LR: 2.5e-04
# GPU Memory: 186/2347 MB | Iterations: 11849
# ==================================================
#
# Epoch 18/42: 100%|██████████████████████████████| 697/697 [07:55<00:00,  1.46bat
# Validation: 100%|██████████████████████████████| 20/20 [00:17<00:00,  1.17batch/
#
# ==================================================
# Epoch 18 | Time: 493.0s
# Loss: 0.0394 | SSIM: 0.9313 | LR: 2.4e-04
# GPU Memory: 187/2347 MB | Iterations: 12546
# ==================================================
#
# Plateau detected at epoch 18! Applying countermeasures...
# LR increased to 2.92e-04
# Augmentation intensity increased to: 1.5
# Epoch 19/42: 100%|██████████████████████████████| 697/697 [08:15<00:00,  1.41bat
# Validation: 100%|██████████████████████████████| 20/20 [00:17<00:00,  1.12batch/
#
# ==================================================
# Epoch 19 | Time: 513.9s
# Loss: 0.0411 | SSIM: 0.9285 | LR: 2.3e-04
# GPU Memory: 187/2347 MB | Iterations: 13243
# ==================================================
#
# Epoch 20/42: 100%|██████████████████████████████| 697/697 [08:21<00:00,  1.39bat
# Validation: 100%|██████████████████████████████| 20/20 [00:18<00:00,  1.10batch/
#
# ==================================================
# Epoch 20 | Time: 519.5s
# Loss: 0.0408 | SSIM: 0.9323 | LR: 2.2e-04
# GPU Memory: 187/2347 MB | Iterations: 13940
# ==================================================
#
# Plateau detected at epoch 20! Applying countermeasures...
# LR increased to 2.64e-04
# Augmentation intensity increased to: 1.5
# Epoch 21/42: 100%|██████████████████████████████| 697/697 [08:08<00:00,  1.43bat
# Validation: 100%|██████████████████████████████| 20/20 [00:17<00:00,  1.16batch/
#
# ==================================================
# Epoch 21 | Time: 506.2s
# Loss: 0.0406 | SSIM: 0.9317 | LR: 2.1e-04
# GPU Memory: 187/2347 MB | Iterations: 14637
# ==================================================
#
# Epoch 22/42: 100%|██████████████████████████████| 697/697 [07:54<00:00,  1.47bat
# Validation: 100%|██████████████████████████████| 20/20 [00:18<00:00,  1.11batch/
#
# ==================================================
# Epoch 22 | Time: 492.0s
# Loss: 0.0401 | SSIM: 0.9297 | LR: 1.9e-04
# GPU Memory: 187/2347 MB | Iterations: 15334
# ==================================================
#
# Plateau detected at epoch 22! Applying countermeasures...
# LR increased to 2.33e-04
# Augmentation intensity increased to: 1.5
# Epoch 23/42: 100%|██████████████████████████████| 697/697 [08:08<00:00,  1.43bat
# Validation: 100%|██████████████████████████████| 20/20 [00:17<00:00,  1.15batch/
#
# ==================================================
# Epoch 23 | Time: 505.7s
# Loss: 0.0402 | SSIM: 0.9349 | LR: 1.8e-04
# GPU Memory: 187/2347 MB | Iterations: 16031
# ==================================================
#
# Epoch 24/42: 100%|██████████████████████████████| 697/697 [08:15<00:00,  1.41bat
# Validation: 100%|██████████████████████████████| 20/20 [00:17<00:00,  1.14batch/
#
# ==================================================
# Epoch 24 | Time: 512.8s
# Loss: 0.0400 | SSIM: 0.9308 | LR: 1.7e-04
# GPU Memory: 187/2347 MB | Iterations: 16728
# ==================================================
#
# Plateau detected at epoch 24! Applying countermeasures...
# LR increased to 2.00e-04
# Augmentation intensity increased to: 1.5
# Epoch 25/42: 100%|██████████████████████████████| 697/697 [08:07<00:00,  1.43bat
# Validation: 100%|██████████████████████████████| 20/20 [00:17<00:00,  1.11batch/
#
# ==================================================
# Epoch 25 | Time: 505.3s
# Loss: 0.0398 | SSIM: 0.9288 | LR: 1.5e-04
# GPU Memory: 187/2347 MB | Iterations: 17425
# ==================================================
#
# Epoch 26/42: 100%|██████████████████████████████| 697/697 [08:07<00:00,  1.43bat
# Validation: 100%|██████████████████████████████| 20/20 [00:16<00:00,  1.19batch/
#
# ==================================================
# Epoch 26 | Time: 504.2s
# Loss: 0.0400 | SSIM: 0.9314 | LR: 1.4e-04
# GPU Memory: 187/2347 MB | Iterations: 18122
# ==================================================
#
# Plateau detected at epoch 26! Applying countermeasures...
# LR increased to 1.67e-04
# Augmentation intensity increased to: 1.5
# Epoch 27/42: 100%|██████████████████████████████| 697/697 [08:07<00:00,  1.43bat
# Validation: 100%|██████████████████████████████| 20/20 [00:17<00:00,  1.14batch/
#
# ==================================================
# Epoch 27 | Time: 504.9s
# Loss: 0.0396 | SSIM: 0.9388 | LR: 1.2e-04
# GPU Memory: 187/2347 MB | Iterations: 18819
# ==================================================
#
# Epoch 28/42: 100%|██████████████████████████████| 697/697 [07:52<00:00,  1.47bat
# Validation: 100%|██████████████████████████████| 20/20 [00:18<00:00,  1.10batch/
#
# ==================================================
# Epoch 28 | Time: 491.0s
# Loss: 0.0396 | SSIM: 0.9352 | LR: 1.1e-04
# GPU Memory: 187/2347 MB | Iterations: 19516
# ==================================================
#
# Plateau detected at epoch 28! Applying countermeasures...
# LR increased to 1.33e-04
# Augmentation intensity increased to: 1.5
# Epoch 29/42: 100%|██████████████████████████████| 697/697 [07:50<00:00,  1.48bat
# Validation: 100%|██████████████████████████████| 20/20 [00:17<00:00,  1.16batch/
#
# ==================================================
# Epoch 29 | Time: 487.6s
# Loss: 0.0396 | SSIM: 0.9322 | LR: 9.8e-05
# GPU Memory: 187/2347 MB | Iterations: 20213
# ==================================================
#
# Epoch 30/42: 100%|██████████████████████████████| 697/697 [08:03<00:00,  1.44bat
# Validation: 100%|██████████████████████████████| 20/20 [00:18<00:00,  1.09batch/
#
# ==================================================
# Epoch 30 | Time: 502.0s
# Loss: 0.0396 | SSIM: 0.9341 | LR: 8.5e-05
# GPU Memory: 187/2347 MB | Iterations: 20910
# ==================================================
#
# Plateau detected at epoch 30! Applying countermeasures...
# LR increased to 1.02e-04
# Augmentation intensity increased to: 1.5
# Epoch 31/42: 100%|██████████████████████████████| 697/697 [08:09<00:00,  1.42bat
# Validation: 100%|██████████████████████████████| 20/20 [00:18<00:00,  1.07batch/
#
# ==================================================
# Epoch 31 | Time: 508.0s
# Loss: 0.0394 | SSIM: 0.9337 | LR: 7.3e-05
# GPU Memory: 187/2347 MB | Iterations: 21607
# ==================================================
#
# Epoch 32/42: 100%|██████████████████████████████| 697/697 [08:14<00:00,  1.41bat
# Validation: 100%|██████████████████████████████| 20/20 [00:18<00:00,  1.11batch/
#
# ==================================================
# Epoch 32 | Time: 512.9s
# Loss: 0.0393 | SSIM: 0.9346 | LR: 6.1e-05
# GPU Memory: 187/2347 MB | Iterations: 22304
# ==================================================
#
# Plateau detected at epoch 32! Applying countermeasures...
# LR increased to 7.31e-05
# Augmentation intensity increased to: 1.5
# Epoch 33/42: 100%|██████████████████████████████| 697/697 [08:14<00:00,  1.41bat
# Validation: 100%|██████████████████████████████| 20/20 [00:17<00:00,  1.14batch/
#
# ==================================================
# Epoch 33 | Time: 512.0s
# Loss: 0.0391 | SSIM: 0.9360 | LR: 5.0e-05
# GPU Memory: 187/2347 MB | Iterations: 23001
# ==================================================
#
# Epoch 34/42: 100%|██████████████████████████████| 697/697 [08:15<00:00,  1.41bat
# Validation: 100%|██████████████████████████████| 20/20 [00:18<00:00,  1.09batch/
#
# ==================================================
# Epoch 34 | Time: 513.3s
# Loss: 0.0390 | SSIM: 0.9330 | LR: 4.0e-05
# GPU Memory: 187/2347 MB | Iterations: 23698
# ==================================================
#
# Plateau detected at epoch 34! Applying countermeasures...
# LR increased to 4.80e-05
# Augmentation intensity increased to: 1.5
# Epoch 35/42: 100%|██████████████████████████████| 697/697 [08:05<00:00,  1.44bat
# Validation: 100%|██████████████████████████████| 20/20 [00:18<00:00,  1.06batch/
#
# ==================================================
# Epoch 35 | Time: 503.9s
# Loss: 0.0390 | SSIM: 0.9331 | LR: 3.1e-05
# GPU Memory: 187/2347 MB | Iterations: 24395
# ==================================================
#
# Epoch 36/42: 100%|██████████████████████████████| 697/697 [07:57<00:00,  1.46bat
# Validation: 100%|██████████████████████████████| 20/20 [00:17<00:00,  1.12batch/
#
# ==================================================
# Epoch 36 | Time: 495.4s
# Loss: 0.0388 | SSIM: 0.9333 | LR: 2.3e-05
# GPU Memory: 187/2347 MB | Iterations: 25092
# ==================================================
#
# Plateau detected at epoch 36! Applying countermeasures...
# LR increased to 2.76e-05
# Augmentation intensity increased to: 1.5
# Epoch 37/42: 100%|██████████████████████████████| 697/697 [07:56<00:00,  1.46bat
# Validation: 100%|██████████████████████████████| 20/20 [00:16<00:00,  1.22batch/
#
# ==================================================
# Epoch 37 | Time: 493.0s
# Loss: 0.0388 | SSIM: 0.9327 | LR: 1.6e-05
# GPU Memory: 187/2347 MB | Iterations: 25789
# ==================================================
#
# Epoch 38/42: 100%|██████████████████████████████| 697/697 [08:03<00:00,  1.44bat
# Validation: 100%|██████████████████████████████| 20/20 [00:17<00:00,  1.12batch/
#
# ==================================================
# Epoch 38 | Time: 501.5s
# Loss: 0.0387 | SSIM: 0.9363 | LR: 1.0e-05
# GPU Memory: 187/2347 MB | Iterations: 26486
# ==================================================
#
# Plateau detected at epoch 38! Applying countermeasures...
# LR increased to 1.24e-05
# Augmentation intensity increased to: 1.5
# Epoch 39/42: 100%|██████████████████████████████| 697/697 [08:03<00:00,  1.44bat
# Validation: 100%|██████████████████████████████| 20/20 [00:17<00:00,  1.14batch/
#
# ==================================================
# Epoch 39 | Time: 500.7s
# Loss: 0.0387 | SSIM: 0.9378 | LR: 5.9e-06
# GPU Memory: 188/2347 MB | Iterations: 27183
# ==================================================
#
# Epoch 40/42: 100%|██████████████████████████████| 697/697 [08:13<00:00,  1.41bat
# Validation: 100%|██████████████████████████████| 20/20 [00:18<00:00,  1.09batch/
#
# ==================================================
# Epoch 40 | Time: 511.4s
# Loss: 0.0387 | SSIM: 0.9342 | LR: 2.6e-06
# GPU Memory: 187/2347 MB | Iterations: 27880
# ==================================================
#
# Plateau detected at epoch 40! Applying countermeasures...
# LR increased to 3.13e-06
# Augmentation intensity increased to: 1.5
# Epoch 41/42: 100%|██████████████████████████████| 697/697 [08:12<00:00,  1.41bat
# Validation: 100%|██████████████████████████████| 20/20 [00:17<00:00,  1.14batch/
#
# ==================================================
# Epoch 41 | Time: 510.4s
# Loss: 0.0388 | SSIM: 0.9314 | LR: 6.5e-07
# GPU Memory: 187/2347 MB | Iterations: 28577
# ==================================================
#
# Epoch 42/42: 100%|██████████████████████████████| 697/697 [08:13<00:00,  1.41bat
# Validation: 100%|██████████████████████████████| 20/20 [00:18<00:00,  1.10batch/
#
# ==================================================
# Epoch 42 | Time: 511.8s
# Loss: 0.0387 | SSIM: 0.9364 | LR: 1.2e-09
# GPU Memory: 187/2347 MB | Iterations: 29274
# ==================================================
#
# Plateau detected at epoch 42! Applying countermeasures...
# LR increased to 1.44e-09
# Augmentation intensity increased to: 1.5
# Training complete! Best SSIM: 0.9423
#
# Download Model: /kaggle/working/final_model.pth
